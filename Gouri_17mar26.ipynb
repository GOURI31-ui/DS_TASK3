# %%
# Created A list named colours
#1.Add " yellow" tothe end of the list

colours=["red","green","blue"]
colours.append("yellow")
print(colours)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 5
#       1 # Created A list named colours
#       2 #1.Add " yellow" tothe end of the list
#       4 colours=["red","green","blue"]
# ----> 5 colours.append("yellow","gray")
#       6 print(colours)
#
# TypeError: list.append() takes exactly one argument (2 given)

# %%
#2. Insert purple at the second of the list
colours=["red","green","blue"]
colours.insert(1,"purple")
print(colours)
# Out:
# ['red', 'purple', 'green', 'blue']

# %%
#3. reverse the entire list 

colours.insert(0,"yellow")
colours.insert(1,"blue")
colours.insert(2,"green")
colours.insert(3,"red")

print(colours)
# Out:
# ['yellow', 'blue', 'green', 'red', 'yellow', 'blue', 'green', 'red', 'red', 'green', 'blue']

# %%
#4.print the final list and its total length
colours.reverse()
print(colours)
print("Final list :",colours)
print("length of list:",len(colours))
# Out:
# ['blue', 'green', 'red', 'red', 'green', 'blue', 'yellow', 'red', 'green', 'blue', 'yellow']
# Final list : ['blue', 'green', 'red', 'red', 'green', 'blue', 'yellow', 'red', 'green', 'blue', 'yellow']
# length of list: 11

# %% [markdown]
# Q2} The slicing Task
# list_numbers = [10,20,30,40,50,60,70,80]

# %%
list_numbers = [10,20,30,40,50,60,70,80]
list_numbers.extend([55,44])
print(list_numbers)
# Out:
# [10, 20, 30, 40, 50, 60, 70, 80, 55, 44]

# %%
#1. Create a new list called sub_list tht contains only the middle elements(30,40,50,60)
sub_list= list_numbers[2:6]

print(sub_list)
# Out:
# [30, 40, 50, 60]

# %%
#2.Replace the value 50 with 500 inside sublist
sub_list[2] =500
print(sub_list)
# Out:
# [30, 40, 500, 60]

# %%
#3.Remove the last element from sub_list
sub_list.pop()
print(sub_list)
# Out:
# [30, 40, 500]
